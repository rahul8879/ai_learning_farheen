# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# lets create sales data
data = {
    'product': np.random.choice(['A', 'B', 'C'], size=100),
    # lets take sales from normal distribution
    'sales': np.random.normal(loc=500, scale=50, size=100).astype(int),
    'dummy_sales': np.random.randint(100, 1000, size=100),
    'date': pd.date_range(start='2023-01-01', periods=100, freq='D')

}

df = pd.DataFrame(data)
df.head(2)
# Out:
#   product  sales  dummy_sales       date
# 0       C    551          259 2023-01-01
# 1       B    467          857 2023-01-02

# %%
df.to_csv('sales_data.csv', index=False)

# %%
# lets plot sales distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['sales'], bins=20, kde=True)
plt.title('Sales Distribution')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
# lets plot dummy sales distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['dummy_sales'], bins=20, kde=True)
plt.title('Dummy Sales Distribution')
plt.xlabel('Dummy Sales')
plt.ylabel('Frequency')
plt.show()

# %%
# avg sales by product
avg_sales = df.groupby('product')['sales'].mean().reset_index()
print("Average Sales by Product:")
print(avg_sales)
# Out:
# Average Sales by Product:
#   product       sales
# 0       A  508.068966
# 1       B  507.941176
# 2       C  493.945946

# %%
print('hello hi fsafsa. dsfsdf. sdfsdf. sfsdfds')
# Out:
# hello hi fsafsa. dsfsdf. sdfsdf. sfsdfds

# %%
print(f"hello world")
# Out:
# hello world

# %%
marks = [85, 90, 78, 92, 88]
total = 0
for mark in marks:
    total += mark
average = total / len(marks)
print(f"Average mark: {average}")

# %%
# list compression marks
marks = [85, 90, 78, 92, 88]
[mark + 5 for mark in marks]
# Out:
# Average mark: 86.6

# %%
updated_marks = []
for mark in [85, 90, 78, 92, 88]:
    updated_marks.append(mark + 5)

# %%
updated_marks
# Out:
# [90, 95, 83, 97, 93]
